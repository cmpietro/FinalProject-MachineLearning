# %%
# import dependencies

import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import New data
# Import Data
reportOhio18 = pd.read_csv("2018-Annual_OH.csv")

reportOhio18
# Out:
#      Edition  Report Type                                     Measure Name  \
# 0       2018  2018 Annual                    Adverse Childhood Experiences
# 1       2018  2018 Annual                    Adverse Childhood Experiences
# 2       2018  2018 Annual                                    Air Pollution
# 3       2018  2018 Annual                                 All Determinants
# 4       2018  2018 Annual                                     All Outcomes
# 5       2018  2018 Annual                                        Behaviors
# 6       2018  2018 Annual                                   Binge Drinking
# 7       2018  2018 Annual                     Binge Drinking - $25-$49,999
# 8       2018  2018 Annual                     Binge Drinking - $50-$74,999
# 9       2018  2018 Annual                 Binge Drinking - $75,000 or More
# 10      2018  2018 Annual                      Binge Drinking - Ages 18-44
# ...

# %%
report18Clean = reportOhio18.Rank != 'NaN'
report18Clean
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
#        ...
# 736    True
# 737    True
# 738    True
# 739    True
# 740    True
# 741    True
# 742    True
# 743    True
# 744    True
# 745    True
# 746    True
# 747    True
# 748    True
# 749    True
# 750    True
# 751    True
# 752    True
# 753    True
# 754    True
# 755    True
# 756    True
# 757    True
# 758    True
# 759    True
# 760    True
# 761    True
# 762    True
# 763    True
# 764    True
# 765    True
# Name: Rank, Length: 766, dtype: bool

# %%
booleans = []
for i in reportOhio18.Rank:
      if i == 'NaN':
            booleans.append(True)
      else:
            booleans.append(False)
booleans
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
# ...

# %%
reportOhio18.columns = ['Measure' if x=='Measure Name(Measure)' else x for x in reportOhio18.columns]

#reportOhio18.rename(columns={"Measure Name": "MeasureName", "State Name": "StateName"})
reportOhio18
# Out:
#      Edition  Report Type                                          Measure  \
# 0       2018  2018 Annual                    Adverse Childhood Experiences
# 1       2018  2018 Annual                    Adverse Childhood Experiences
# 2       2018  2018 Annual                                    Air Pollution
# 3       2018  2018 Annual                                 All Determinants
# 4       2018  2018 Annual                                     All Outcomes
# 5       2018  2018 Annual                                        Behaviors
# 6       2018  2018 Annual                                   Binge Drinking
# 7       2018  2018 Annual                     Binge Drinking - $25-$49,999
# 8       2018  2018 Annual                     Binge Drinking - $50-$74,999
# 9       2018  2018 Annual                 Binge Drinking - $75,000 or More
# 10      2018  2018 Annual                      Binge Drinking - Ages 18-44
# ...

# %%
reportOhio18.Measure.unique()
# Out:
# array(['Adverse Childhood Experiences', 'Air Pollution',
#        'All Determinants', 'All Outcomes', 'Behaviors', 'Binge Drinking',
#        'Binge Drinking - $25-$49,999', 'Binge Drinking - $50-$74,999',
#        'Binge Drinking - $75,000 or More', 'Binge Drinking - Ages 18-44',
#        'Binge Drinking - Ages 45-64', 'Binge Drinking - Ages 65+',
#        'Binge Drinking - American Indian/Alaskan Native',
#        'Binge Drinking - Asian', 'Binge Drinking - Black',
#        'Binge Drinking - College Grad', 'Binge Drinking - Female',
#        'Binge Drinking - Hawaiian/Pacific Islander',
#        'Binge Drinking - High School Grad', 'Binge Drinking - Hispanic',
#        'Binge Drinking - Less Than $25,000',
#        'Binge Drinking - Less than High School', 'Binge Drinking - Male',
#        'Binge Drinking - Multiracial', 'Binge Drinking - Other Race',
#        'Binge Drinking - Rural', 'Binge Drinking - Some College',
#        'Binge Drinking - Suburban', 'Binge Drinking - Urban',
# ...

# %%
# Import New data
# Import Data
reportOhio17 = pd.read_csv("2017-Annual_OH.csv")

reportOhio17.head()
# Out:
#    Edition  Report Type      Measure Name State Name  Rank   Value  Score  \
# 0     2017  2017 Annual     Air Pollution       Ohio  45.0   9.600  0.650
# 1     2017  2017 Annual  All Determinants       Ohio  40.0  -0.266 -0.266
# 2     2017  2017 Annual      All Outcomes       Ohio  39.0  -0.144 -0.144
# 3     2017  2017 Annual         Behaviors       Ohio  46.0  -0.212 -0.212
# 4     2017  2017 Annual    Binge Drinking       Ohio  31.0  17.900  0.350
#
#    Lower CI  Upper CI                                             Source  \
# 0       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 1       0.0       0.0        America's Health Rankings composite measure
# 2       0.0       0.0        America's Health Rankings composite measure
# 3       0.0       0.0        America's Health Rankings composite measure
# 4      19.1      16.7    CDC, Behavioral Risk Factor Surveillance System
#
#   Source Year
# 0   2014-2016
# 1        2017
# 2        2017
# 3        2017
# ...

# %%
# Import New data
# Import Data
reportOhio16 = pd.read_csv("2016-Annual_OH.csv")

reportOhio16.head()
# Out:
#    Edition  Report Type      Measure Name State Name  Rank   Value  Score  \
# 0     2016  2016 Annual     Air Pollution       Ohio  46.0  10.200  0.880
# 1     2016  2016 Annual  All Determinants       Ohio  39.0  -0.251 -0.251
# 2     2016  2016 Annual      All Outcomes       Ohio  40.0  -0.140 -0.140
# 3     2016  2016 Annual         Behaviors       Ohio  44.0  -0.163 -0.163
# 4     2016  2016 Annual    Binge Drinking       Ohio  40.0  18.200  0.670
#
#    Lower CI  Upper CI                                             Source  \
# 0       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 1       NaN       NaN        America's Health Rankings composite measure
# 2       NaN       NaN        America's Health Rankings composite measure
# 3       NaN       NaN        America's Health Rankings composite measure
# 4      19.6      16.9    CDC, Behavioral Risk Factor Surveillance System
#
#   Source Year
# 0   2013-2015
# 1        2016
# 2        2016
# 3        2016
# ...

# %%
# Import New data
# Import Data
reportOhio15 = pd.read_csv("2015-Annual_OH.csv")

reportOhio15.head()
# Out:
#    Edition  Report Type      Measure Name State Name  Rank   Value  Score  \
# 0     2015  2015 Annual     Air Pollution       Ohio  45.0  10.600   0.65
# 1     2015  2015 Annual  All Determinants       Ohio  36.0  -0.226    NaN
# 2     2015  2015 Annual      All Outcomes       Ohio  41.0  -0.140    NaN
# 3     2015  2015 Annual         Behaviors       Ohio  44.0  -0.157    NaN
# 4     2015  2015 Annual    Binge Drinking       Ohio  39.0  18.000   0.68
#
#    Lower CI  Upper CI                                             Source  \
# 0       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 1       NaN       NaN        America's Health Rankings composite measure
# 2       NaN       NaN        America's Health Rankings composite measure
# 3       NaN       NaN        America's Health Rankings composite measure
# 4      19.3      16.8    CDC, Behavioral Risk Factor Surveillance System
#
#   Source Year
# 0   2012-2014
# 1        2015
# 2        2015
# 3        2015
# ...
