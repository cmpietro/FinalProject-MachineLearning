# %%
# import dependencies

import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# http://publicapps.odh.ohio.gov/EDW/DataBrowser/Browse/Mortality

# %%
# Import Data
#Ohio mortality rates by year and county

ohioRates = pd.read_csv("Infant Mortality Rates by Ohio Counties.csv")

ohioRates.head()
# Out:
#    DEATH COUNTY  DEATHS
# 0   2007  Adams     294
# 1   2008  Adams     314
# 2   2009  Adams     314
# 3   2010  Adams     324
# 4   2011  Adams     309

# %%
ohioRates.pivot(index='DEATH', columns='COUNTY', values='DEATHS')
# Out:
# COUNTY  Adams  Allen  Ashland  Ashtabula  Athens  Auglaize  Belmont  Brown  \
# DEATH
# 2007      294   1030      480       1100     465       505      894    434
# 2008      314   1045      502       1112     456       465      913    480
# 2009      314   1045      535       1088     466       461      853    436
# 2010      324   1081      527       1109     512       469      939    466
# 2011      309   1051      531       1180     500       459      923    465
# 2012      328   1111      565       1136     455       500      919    467
# 2013      337   1083      548       1193     412       476      874    501
# 2014      314   1096      549       1156     488       480      824    485
# 2015      347   1111      536       1206     513       500      893    514
# 2016      367   1131      609       1172     463       509      890    521
# 2017      352   1142      568       1233     496       479      924    541
# ...

# %%
ohioScat = ohioRates.plot.scatter(x='DEATHS', y='DEATHS', c='DEATH', colormap='viridis' )

# %%
ohioRates.plot(x ='DEATHS', y='DEATH', kind = 'line')

# %%
# Import Data
ohioIMRates = pd.read_csv("Infant (Under 1)Mortality Rates by Ohio Counties.csv")

ohioIMRates.head()
# Out:
#    YEAR COUNTY  DEATHS
# 0  2007  Adams       5
# 1  2008  Adams       1
# 2  2009  Adams       8
# 3  2010  Adams       2
# 4  2011  Adams       6

# %%
ohioIMRates.pivot(index='DEATHS', columns='COUNTY', values='YEAR')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-3438cd9bd9e3> in <module>
# ----> 1 ohioIMRates.pivot(index='DEATHS', columns='COUNTY', values='YEAR')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    5626     def pivot(self, index=None, columns=None, values=None):
#    5627         from pandas.core.reshape.pivot import pivot
# -> 5628         return pivot(self, index=index, columns=columns, values=values)
#    5629
#    5630     _shared_docs['pivot_table'] = """
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     386             indexed = data._constructor_sliced(data[values].values,
#     387                                                index=index)
# --> 388     return indexed.unstack(columns)
#     389
#     390
#
# ...

# %%
ohioIMRates.plot(x ='YEAR', y='DEATHS', kind = 'bar')

# %%
# Import New data
# Import Data
ohioMI2017 = pd.read_csv("poverty_rate/median income per county 2017.csv")

ohioMI2017.head()
# Out:
#             Id  Id2 Geography   Target Geo Id  Target Geo Id2  \
# 0  0400000US39   39      Ohio     0400000US39              39
# 1  0400000US39   39      Ohio  0500000US39001           39001
# 2  0400000US39   39      Ohio  0500000US39003           39003
# 3  0400000US39   39      Ohio  0500000US39005           39005
# 4  0400000US39   39      Ohio  0500000US39007           39007
#
#            Geographic Area Geographic Area.1  Dollar  Margin of Error
# 0                     Ohio              Ohio   52407              153
# 1      Ohio - Adams County      Adams County   36320             2651
# 2      Ohio - Allen County      Allen County   47905             1708
# 3    Ohio - Ashland County    Ashland County   50893             1608
# 4  Ohio - Ashtabula County  Ashtabula County   43017             1597

# %%
# Import New data
# Import Data
reportOhio18 = pd.read_csv("infant_mortality/ohioOnly/2018-Annual_OH.csv")

reportOhio18
# Out:
#      Edition  Report Type                                     Measure Name  \
# 0       2018  2018 Annual                    Adverse Childhood Experiences
# 1       2018  2018 Annual                    Adverse Childhood Experiences
# 2       2018  2018 Annual                                    Air Pollution
# 3       2018  2018 Annual                                 All Determinants
# 4       2018  2018 Annual                                     All Outcomes
# 5       2018  2018 Annual                                        Behaviors
# 6       2018  2018 Annual                                   Binge Drinking
# 7       2018  2018 Annual                     Binge Drinking - $25-$49,999
# 8       2018  2018 Annual                     Binge Drinking - $50-$74,999
# 9       2018  2018 Annual                 Binge Drinking - $75,000 or More
# 10      2018  2018 Annual                      Binge Drinking - Ages 18-44
# ...

# %%
ohio18 = reportOhio18.plot.scatter(x='Rank', y='Score', c='Blue')

# %%
# Import New data
# Import Data
reportOhio17 = pd.read_csv("infant_mortality/ohioOnly/2017-Annual_OH.csv")

reportOhio17.head()
# Out:
#    Edition  Report Type      Measure Name State Name  Rank   Value  Score  \
# 0     2017  2017 Annual     Air Pollution       Ohio  45.0   9.600  0.650
# 1     2017  2017 Annual  All Determinants       Ohio  40.0  -0.266 -0.266
# 2     2017  2017 Annual      All Outcomes       Ohio  39.0  -0.144 -0.144
# 3     2017  2017 Annual         Behaviors       Ohio  46.0  -0.212 -0.212
# 4     2017  2017 Annual    Binge Drinking       Ohio  31.0  17.900  0.350
#
#    Lower CI  Upper CI                                             Source  \
# 0       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 1       0.0       0.0        America's Health Rankings composite measure
# 2       0.0       0.0        America's Health Rankings composite measure
# 3       0.0       0.0        America's Health Rankings composite measure
# 4      19.1      16.7    CDC, Behavioral Risk Factor Surveillance System
#
#   Source Year
# 0   2014-2016
# 1        2017
# 2        2017
# 3        2017
# ...

# %%
ohio17 = reportOhio17.plot.scatter(x='Rank', y='Score', c='Blue')

# %%
# Import New data
# Import Data
reportOhio16 = pd.read_csv("infant_mortality/ohioOnly/2016-Annual_OH.csv")

reportOhio16.head()
# Out:
#    Edition  Report Type      Measure Name State Name  Rank   Value  Score  \
# 0     2016  2016 Annual     Air Pollution       Ohio  46.0  10.200  0.880
# 1     2016  2016 Annual  All Determinants       Ohio  39.0  -0.251 -0.251
# 2     2016  2016 Annual      All Outcomes       Ohio  40.0  -0.140 -0.140
# 3     2016  2016 Annual         Behaviors       Ohio  44.0  -0.163 -0.163
# 4     2016  2016 Annual    Binge Drinking       Ohio  40.0  18.200  0.670
#
#    Lower CI  Upper CI                                             Source  \
# 0       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 1       NaN       NaN        America's Health Rankings composite measure
# 2       NaN       NaN        America's Health Rankings composite measure
# 3       NaN       NaN        America's Health Rankings composite measure
# 4      19.6      16.9    CDC, Behavioral Risk Factor Surveillance System
#
#   Source Year
# 0   2013-2015
# 1        2016
# 2        2016
# 3        2016
# ...

# %%
ohio16 = reportOhio16.plot.scatter(x='Rank', y='Score', c='Blue')

# %%
# Import New data
# Import Data
reportOhio15 = pd.read_csv("infant_mortality/ohioOnly/2015-Annual_OH.csv")

reportOhio15.head()
# Out:
#    Edition  Report Type      Measure Name State Name  Rank   Value  Score  \
# 0     2015  2015 Annual     Air Pollution       Ohio  45.0  10.600   0.65
# 1     2015  2015 Annual  All Determinants       Ohio  36.0  -0.226    NaN
# 2     2015  2015 Annual      All Outcomes       Ohio  41.0  -0.140    NaN
# 3     2015  2015 Annual         Behaviors       Ohio  44.0  -0.157    NaN
# 4     2015  2015 Annual    Binge Drinking       Ohio  39.0  18.000   0.68
#
#    Lower CI  Upper CI                                             Source  \
# 0       NaN       NaN  U.S. Environmental Protection Agency; U.S. Cen...
# 1       NaN       NaN        America's Health Rankings composite measure
# 2       NaN       NaN        America's Health Rankings composite measure
# 3       NaN       NaN        America's Health Rankings composite measure
# 4      19.3      16.8    CDC, Behavioral Risk Factor Surveillance System
#
#   Source Year
# 0   2012-2014
# 1        2015
# 2        2015
# 3        2015
# ...

# %%
ohio15 = reportOhio15.plot.scatter(x='Rank', y='Score', c='Blue')
