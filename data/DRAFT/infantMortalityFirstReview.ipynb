# %%
# import dependencies

import pandas as pd

# %% [markdown]
# # DATA Evaluation:  Infant Mortality

# %% [markdown]
# ### C:\Users\carol\Documents\GitHub\FinalProject-MachineLearning\data\DRAFT

# %% [markdown]
# https://wonder.cdc.gov/

# %%
# Import Data
wonderBirthData = pd.read_csv("wonderCDCBirthdata_2016-2018.txt", sep='\t', engine='python')

wonderBirthData.head()
# Out:
#   Notes State of Residence  State of Residence Code   County of Residence  \
# 0   NaN            Alabama                      1.0    Baldwin County, AL
# 1   NaN            Alabama                      1.0    Calhoun County, AL
# 2   NaN            Alabama                      1.0     Etowah County, AL
# 3   NaN            Alabama                      1.0    Houston County, AL
# 4   NaN            Alabama                      1.0  Jefferson County, AL
#
#    County of Residence Code 2013 Metro/Nonmetro 2013 Metro/Nonmetro Code  \
# 0                    1003.0               Metro                    Metro
# 1                    1015.0               Metro                    Metro
# 2                    1055.0               Metro                    Metro
# 3                    1069.0               Metro                    Metro
# 4                    1073.0               Metro                    Metro
#
#    Births % of Total Births  Average Age of Mother (years)  \
# ...

# %%
wonderBirthData.shape
# Out:
# (724, 15)

# %%
wonderBirthData.describe()
# Out:
#        State of Residence Code  County of Residence Code         Births  \
# count               668.000000                668.000000     668.000000
# mean                 29.122754              29335.205090    5676.215569
# std                  15.448028              15483.692928    8025.967034
# min                   1.000000               1003.000000     308.000000
# 25%                  16.000000              16999.000000    1719.250000
# 50%                  29.000000              29999.000000    2930.000000
# 75%                  42.000000              42041.500000    6757.500000
# max                  56.000000              56999.000000  110271.000000
#
#        Average Age of Mother (years)  Average OE Gestational Age (weeks)  \
# count                     668.000000                          668.000000
# mean                       28.785284                           38.448518
# std                         1.335792                            0.205803
# ...

# %%
wonderBirthData.drop(columns=['Notes'])
# Out:
#     State of Residence  State of Residence Code        County of Residence  \
# 0              Alabama                      1.0         Baldwin County, AL
# 1              Alabama                      1.0         Calhoun County, AL
# 2              Alabama                      1.0          Etowah County, AL
# 3              Alabama                      1.0         Houston County, AL
# 4              Alabama                      1.0       Jefferson County, AL
# 5              Alabama                      1.0             Lee County, AL
# 6              Alabama                      1.0         Madison County, AL
# 7              Alabama                      1.0          Mobile County, AL
# 8              Alabama                      1.0      Montgomery County, AL
# 9              Alabama                      1.0          Morgan County, AL
# 10             Alabama                      1.0          Shelby County, AL
# ...

# %% [markdown]
# http://publicapps.odh.ohio.gov/EDW/DataBrowser/Browse/Mortality

# %%
# Import Data
ohioRates = pd.read_csv("Infant Mortality Rates by Ohio Counties.csv")

ohioRates.head()
# Out:
#    DEATH COUNTY  DEATHS
# 0   2007  Adams     294
# 1   2008  Adams     314
# 2   2009  Adams     314
# 3   2010  Adams     324
# 4   2011  Adams     309

# %%
ohioRates.shape
# Out:
# (1170, 3)

# %%
ohioRates.describe
# Out:
# <bound method NDFrame.describe of       DEATH    COUNTY  DEATHS
# 0      2007     Adams     294
# 1      2008     Adams     314
# 2      2009     Adams     314
# 3      2010     Adams     324
# 4      2011     Adams     309
# 5      2012     Adams     328
# 6      2013     Adams     337
# 7      2014     Adams     314
# 8      2015     Adams     347
# 9      2016     Adams     367
# 10     2017     Adams     352
# 11     2018     Adams     338
# 12     2019     Adams     282
# 13     2007     Allen    1030
# 14     2008     Allen    1045
# 15     2009     Allen    1045
# 16     2010     Allen    1081
# 17     2011     Allen    1051
# 18     2012     Allen    1111
# 19     2013     Allen    1083
# 20     2014     Allen    1096
# 21     2015     Allen    1111
# 22     2016     Allen    1131
# 23     2017     Allen    1142
# 24     2018     Allen    1161
# 25     2019     Allen     896
# 26     2007   Ashland     480
# 27     2008   Ashland     502
# 28     2009   Ashland     535
# ...

# %%
# Import Data
ohioIMRates = pd.read_csv("Infant (Under 1)Mortality Rates by Ohio Counties.csv")

ohioIMRates.head()
# Out:
#    YEAR COUNTY  DEATHS
# 0  2007  Adams       5
# 1  2008  Adams       1
# 2  2009  Adams       8
# 3  2010  Adams       2
# 4  2011  Adams       6

# %%
ohioIMRates.shape
# Out:
# (1170, 3)

# %%
ohioIMRates.describe()
# Out:
#               YEAR       DEATHS
# count  1170.000000  1170.000000
# mean   2013.000000    11.289744
# std       3.743257    24.413160
# min    2007.000000     0.000000
# 25%    2010.000000     2.000000
# 50%    2013.000000     4.000000
# 75%    2016.000000     9.000000
# max    2019.000000   174.000000

# %% [markdown]
# ###    C:\Users\carol\Documents\GitHub\FinalProject-MachineLearning\data\DRAFT\breastfeeding

# %%
# Import Data
unicefBFdata = pd.read_excel("breastfeeding/UNICEF_Expanded_Global_Databases_Early_Initiation_May2019.xlsx")

unicefBFdata.head()
# Out:
#               Unnamed: 0                                         Unnamed: 1  \
# 0                    NaN  UNICEF Global database on Infant and Young Chi...
# 1                    NaN  Ever Breastfed and Early Initiationof Breastfe...
# 2                    NaN                                                NaN
# 3       Indicator Names:                  Early Initiation of Breastfeeding
# 4  Indicator Definitions  Percentage of newborns put to the breast withi...
#
#                               Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0                                    NaN         NaN         NaN         NaN
# 1                                    NaN         NaN         NaN         NaN
# 2                                    NaN         NaN         NaN         NaN
# 3                         Ever Breastfed         NaN         NaN         NaN
# 4  Percentage of newborns ever breastfed         NaN         NaN         NaN
#
# ...

# %%
unicefBFdata.shape
# Out:
# (91, 15)

# %% [markdown]
# ### C:\Users\carol\Documents\GitHub\FinalProject-MachineLearning\data\DRAFT\infant_mortality

# %%
# Import New data
# Import Data
IMState2017 = pd.read_csv("infant_mortality/Infant Mortality Rates by State 2017.csv")

IMState2017.head()
# Out:
#      YEAR STATE  RATE DEATHS                                               URL
# 0  2017.0    AL   7.4    434        /nchs/pressroom/states/alabama/alabama.htm
# 1  2017.0    AK   5.6     59          /nchs/pressroom/states/alaska/alaska.htm
# 2  2017.0    AZ   5.7    469        /nchs/pressroom/states/arizona/arizona.htm
# 3  2017.0    AR   8.2    307      /nchs/pressroom/states/arkansas/arkansas.htm
# 4  2017.0    CA   4.2  1,973  /nchs/pressroom/states/california/california.htm

# %%
# Clean Data
stateIM2017cl = stateIM2017.drop(columns=['URL'])
stateIM2017cl.head()
# Out:
#      YEAR STATE  RATE DEATHS
# 0  2017.0    AL   7.4    434
# 1  2017.0    AK   5.6     59
# 2  2017.0    AZ   5.7    469
# 3  2017.0    AR   8.2    307
# 4  2017.0    CA   4.2  1,973

# %%
# view and describe data
stateIM2017.shape
# Out:
# (251, 5)

# %%
stateIM2017.describe()
# Out:
#               YEAR        RATE
# count   250.000000  250.000000
# mean   2013.400000    6.228000
# std       4.326067    1.385965
# min    2005.000000    0.000000
# 25%    2014.000000    5.225000
# 50%    2015.000000    6.100000
# 75%    2016.000000    7.175000
# max    2017.000000   11.500000

# %%
# Import New data
# Import Data
IMState = pd.read_csv("infant_mortality/Infant Mortality Rates by State_multiyear.csv")

IMState.head()
# Out:
#      YEAR STATE  RATE DEATHS                                               URL
# 0  2017.0    AL   7.4    434        /nchs/pressroom/states/alabama/alabama.htm
# 1  2017.0    AK   5.6     59          /nchs/pressroom/states/alaska/alaska.htm
# 2  2017.0    AZ   5.7    469        /nchs/pressroom/states/arizona/arizona.htm
# 3  2017.0    AR   8.2    307      /nchs/pressroom/states/arkansas/arkansas.htm
# 4  2017.0    CA   4.2  1,973  /nchs/pressroom/states/california/california.htm

# %%
IMState.shape
# Out:
# (251, 5)

# %%
# Import New data
# Import Data
nchsICMrates = pd.read_csv("infant_mortality/nchs-childhood-mortality-rates.csv")

nchsICMrates.head()
# Out:
#    Year  Age Group  Death Rate
# 0  1900  5-9 years       466.1
# 1  1901  5-9 years       427.6
# 2  1902  5-9 years       403.3
# 3  1903  5-9 years       414.7
# 4  1904  5-9 years       425.0

# %%
nchsICMrates.shape
# Out:
# (464, 3)

# %%
nchsICMrates.describe()
# Out:
#               Year   Death Rate
# count   464.000000   464.000000
# mean   1957.500000   197.254526
# std      33.521213   295.731958
# min    1900.000000    11.400000
# 25%    1928.750000    41.525000
# 50%    1957.500000    91.850000
# 75%    1986.250000   230.025000
# max    2015.000000  1983.800000

# %%
# Import Data
nchsICMrates19152013 = pd.read_csv("infant_mortality/nchs-infant-and-neonatal-mortality-rates-united-states-1915-2013.csv")

nchsICMrates19152013.head()
# Out:
#        Type  Year  Mortality Rate
# 0  Neonatal  1915            44.4
# 1  Neonatal  1916            44.1
# 2  Neonatal  1917            43.4
# 3  Neonatal  1918            44.2
# 4  Neonatal  1919            41.5

# %%
nchsICMrates19152013.shape
# Out:
# (198, 3)

# %%
nchsICMrates19152013.describe()
# Out:
#              Year  Mortality Rate
# count   198.00000      198.000000
# mean   1964.00000       25.085152
# std      28.64982       21.618889
# min    1915.00000        4.010000
# 25%    1939.25000        7.625000
# 50%    1964.00000       19.100000
# 75%    1988.75000       33.950000
# max    2013.00000      101.000000

# %%
# Import Data
nchsICMrates19152013RACE = pd.read_csv("infant_mortality/nchs-infant-mortality-rates-by-race-united-states-1915-2013.csv")

nchsICMrates19152013RACE.head()
# Out:
#     Race  Year  Infant Mortality Rate
# 0  Black  1915                  195.2
# 1  Black  1916                  184.3
# 2  Black  1917                  173.4
# 3  Black  1918                  162.5
# 4  Black  1919                  134.3

# %%
nchsICMrates19152013RACE.shape
# Out:
# (198, 3)

# %%
nchsICMrates19152013RACE.describe()
# Out:
#              Year  Infant Mortality Rate
# count   198.00000              198.00000
# mean   1964.00000               40.10101
# std      28.64982               36.61733
# min    1915.00000                5.07000
# 25%    1939.25000               14.00000
# 50%    1964.00000               25.65000
# 75%    1988.75000               53.20000
# max    2013.00000              195.20000

# %% [markdown]
# ### C:\Users\carol\Documents\GitHub\FinalProject-MachineLearning\data\DRAFT\infant_mortality\CDC_LinkedBirthDeathRates

# %%
# Import Data
stateIM2003 = pd.read_csv("infant_mortality/CDC_LinkedBirthDeathRates/Linked Birth  Infant Death Records, 2003-2006.txt", sep='\t', engine='python')

stateIM2003.head()
# Out:
#   Notes    State  State Code                County  County Code  \
# 0   NaN  Alabama         1.0  Jefferson County, AL       1073.0
# 1   NaN  Alabama         1.0  Jefferson County, AL       1073.0
# 2   NaN  Alabama         1.0  Jefferson County, AL       1073.0
# 3   NaN  Alabama         1.0  Jefferson County, AL       1073.0
# 4   NaN  Alabama         1.0  Jefferson County, AL       1073.0
#
#        Mother's Bridged Race Mother's Bridged Race Code  Gender Gender Code  \
# 0  Black or African American                     2054-5  Female           F
# 1  Black or African American                     2054-5  Female           F
# 2  Black or African American                     2054-5  Female           F
# 3  Black or African American                     2054-5  Female           F
# 4  Black or African American                     2054-5    Male           M
#
#    Year of Death  Year of Death Code  Deaths  Births Death Rate
# ...

# %%
stateIM2003.shape
# Out:
# (2699, 14)

# %%
stateIM2003.describe()
# Out:
#         State Code   County Code  Year of Death  Year of Death Code  \
# count  2652.000000   2652.000000    2652.000000         2652.000000
# mean     27.473982  27750.484917    2004.515837         2004.515837
# std      15.320334  15366.721084       1.120828            1.120828
# min       1.000000   1073.000000    2003.000000         2003.000000
# 25%      12.000000  12999.000000    2004.000000         2004.000000
# 50%      27.000000  27123.000000    2005.000000         2005.000000
# 75%      39.000000  39999.000000    2006.000000         2006.000000
# max      56.000000  56999.000000    2006.000000         2006.000000
#
#             Deaths        Births
# count  2652.000000   2652.000000
# mean     37.897436   5449.886501
# std      44.026963   7028.249395
# min      10.000000    284.000000
# 25%      14.000000   1839.500000
# 50%      21.000000   3209.000000
# 75%      38.000000   5692.500000
# max     377.000000  62946.000000

# %%
# Import Data
stateIM2007 = pd.read_csv("infant_mortality/CDC_LinkedBirthDeathRates/Linked Birth  Infant Death Records, 2007-2017 RACE and Year.txt", sep='\t', engine='python')

stateIM2007.head(100)
# Out:
#    Notes                 State  State Code                     County  \
# 0    NaN               Alabama         1.0       Jefferson County, AL
# 1    NaN               Alabama         1.0       Jefferson County, AL
# 2    NaN               Alabama         1.0       Jefferson County, AL
# 3    NaN               Alabama         1.0          Mobile County, AL
# 4    NaN               Alabama         1.0          Mobile County, AL
# 5    NaN               Alabama         1.0  Unidentified Counties, AL
# 6    NaN               Alabama         1.0  Unidentified Counties, AL
# 7    NaN               Alabama         1.0  Unidentified Counties, AL
# 8    NaN               Alabama         1.0  Unidentified Counties, AL
# 9    NaN                Alaska         2.0  Unidentified Counties, AK
# 10   NaN               Arizona         4.0        Maricopa County, AZ
# 11   NaN               Arizona         4.0        Maricopa County, AZ
# ...

# %%
stateIM2007.shape
# Out:
# (633, 14)

# %%
stateIM2007.describe()
# Out:
#        State Code   County Code  Year of Death  Year of Death Code  \
# count  568.000000    568.000000          568.0               568.0
# mean    28.014085  28317.753521         2017.0              2017.0
# std     15.503421  15551.851482            0.0                 0.0
# min      1.000000   1073.000000         2017.0              2017.0
# 25%     12.750000  13038.000000         2017.0              2017.0
# 50%     29.000000  29095.000000         2017.0              2017.0
# 75%     40.000000  40999.000000         2017.0              2017.0
# max     56.000000  56999.000000         2017.0              2017.0
#
#            Deaths        Births
# count  568.000000    568.000000
# mean    31.232394   5118.459507
# std     32.776334   5901.403448
# min     10.000000    571.000000
# 25%     13.000000   1837.500000
# 50%     18.000000   3090.000000
# 75%     35.000000   5529.500000
# max    253.000000  43362.000000

# %%
# Import Data
stateIM2007noRG = pd.read_csv("infant_mortality/CDC_LinkedBirthDeathRates/Linked Birth  Infant Death Records, 2007-2017.txt", sep='\t', engine='python')

stateIM2007noRG.head(100)
# Out:
#    Notes               Census Region Census Region Code          State  \
# 0    NaN  Census Region 1: Northeast            CENS-R1    Connecticut
# 1    NaN  Census Region 1: Northeast            CENS-R1    Connecticut
# 2    NaN  Census Region 1: Northeast            CENS-R1    Connecticut
# 3    NaN  Census Region 1: Northeast            CENS-R1    Connecticut
# 4    NaN  Census Region 1: Northeast            CENS-R1    Connecticut
# 5    NaN  Census Region 1: Northeast            CENS-R1          Maine
# 6    NaN  Census Region 1: Northeast            CENS-R1          Maine
# 7    NaN  Census Region 1: Northeast            CENS-R1  Massachusetts
# 8    NaN  Census Region 1: Northeast            CENS-R1  Massachusetts
# 9    NaN  Census Region 1: Northeast            CENS-R1  Massachusetts
# 10   NaN  Census Region 1: Northeast            CENS-R1  Massachusetts
# 11   NaN  Census Region 1: Northeast            CENS-R1  Massachusetts
# ...

# %%
stateIM2007noRG.shape
# Out:
# (366, 10)

# %%
stateIM2007noRG.describe()
# Out:
#        State Code   County Code      Deaths         Births
# count  305.000000    305.000000  305.000000     305.000000
# mean    28.206557  28439.127869   73.055738   12582.760656
# std     15.517179  15548.027856   91.816036   14856.574701
# min      1.000000   1073.000000   10.000000    2550.000000
# 25%     12.000000  12999.000000   23.000000    4466.000000
# 50%     29.000000  29183.000000   38.000000    7130.000000
# 75%     42.000000  42003.000000   73.000000   13326.000000
# max     56.000000  56999.000000  587.000000  116950.000000

# %%
# Import Data
stateIMwonder = pd.read_csv("infant_mortality/CDC_LinkedBirthDeathRates/wonderCDCAllStatesRatesOnly.txt", sep='\t', engine='python')

stateIMwonder.head(100)
# Out:
#    notes               Census Region Census Region Code          State  \
# 0    NaN  Census Region 1: Northeast            CENS-R1    Connecticut
# 1    NaN  Census Region 1: Northeast            CENS-R1    Connecticut
# 2    NaN  Census Region 1: Northeast            CENS-R1    Connecticut
# 3    NaN  Census Region 1: Northeast            CENS-R1    Connecticut
# 4    NaN  Census Region 1: Northeast            CENS-R1    Connecticut
# 5    NaN  Census Region 1: Northeast            CENS-R1          Maine
# 6    NaN  Census Region 1: Northeast            CENS-R1          Maine
# 7    NaN  Census Region 1: Northeast            CENS-R1  Massachusetts
# 8    NaN  Census Region 1: Northeast            CENS-R1  Massachusetts
# 9    NaN  Census Region 1: Northeast            CENS-R1  Massachusetts
# 10   NaN  Census Region 1: Northeast            CENS-R1  Massachusetts
# 11   NaN  Census Region 1: Northeast            CENS-R1  Massachusetts
# ...

# %%
stateIMwonder.shape
# Out:
# (367, 12)

# %%
stateIMwonder.describe()
# Out:
#        State Code   County Code  Year of Death  Year of Death Code  \
# count  305.000000    305.000000          305.0               305.0
# mean    28.206557  28439.127869         2017.0              2017.0
# std     15.517179  15548.027856            0.0                 0.0
# min      1.000000   1073.000000         2017.0              2017.0
# 25%     12.000000  12999.000000         2017.0              2017.0
# 50%     29.000000  29183.000000         2017.0              2017.0
# 75%     42.000000  42003.000000         2017.0              2017.0
# max     56.000000  56999.000000         2017.0              2017.0
#
#            Deaths         Births
# count  305.000000     305.000000
# mean    73.055738   12582.760656
# std     91.816036   14856.574701
# min     10.000000    2550.000000
# 25%     23.000000    4466.000000
# 50%     38.000000    7130.000000
# 75%     73.000000   13326.000000
# max    587.000000  116950.000000

# %% [markdown]
# ## C:\Users\carol\Documents\GitHub\FinalProject-MachineLearning\data\DRAFT\infant_mortality\ohioOnly

# %% [markdown]
# ## C:\Users\carol\Documents\GitHub\FinalProject-MachineLearning\data\DRAFT\infant_mortality\unicef_global_rates

# %%
# Import Data
unicefGlobalRate = pd.read_excel("infant_mortality/unicef_global_rates/IMR_mortality_rate_2019.xlsx")

unicefGlobalRate.head()
# Out:
#                                Unnamed: 0 Unnamed: 1 UNICEF GLOBAL DATABASES  \
# 0                                     NaN        NaN                     NaN
# 1                                     NaN        NaN                     NaN
# 2               Child Mortality Estimates        NaN                     NaN
# 3  Country-specific infant mortality rate        NaN                     NaN
# 4                                     NaN        NaN                     NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
# ...

# %% [markdown]
# ## C:\Users\carol\Documents\GitHub\FinalProject-MachineLearning\data\DRAFT\infant_race

# %%
# Import Data
MICHdf = pd.read_excel("infant_race/MICH-1.3-data.xlsx")

MICHdf.head()
# Out:
#        Unnamed: 0     Unnamed: 1      1998 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0        PopTitle      Geography  Estimate     StdErr    LowerCI    UpperCI
# 1           Total  United States       7.2      0.043        7.1        7.3
# 2  Sex (of child)            NaN       NaN        NaN        NaN        NaN
# 3            Male  United States       7.8      0.062        7.7        7.9
# 4          Female  United States       6.5      0.058        6.4        6.6
#
#        1999 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 68 Unnamed: 69  \
# 0  Estimate     StdErr    LowerCI    UpperCI  ...     LowerCI     UpperCI
# 1         7      0.042        6.9        7.1  ...         5.7         5.9
# 2       NaN        NaN        NaN        NaN  ...         NaN         NaN
# 3       7.7      0.062        7.6        7.8  ...         6.2         6.4
# 4       6.3      0.057        6.2        6.4  ...         5.2         5.4
#
# ...

# %%
MICHdf.shape
# Out:
# (44, 78)

# %%
MICHdf.describe()
# Out:
#                                                Unnamed: 0     Unnamed: 1  \
# count                                                  42             25
# unique                                                 42              2
# top           Black or African American, not Hispanic ...  United States
# freq                                                    1             24
#
#         1998  Unnamed: 3  Unnamed: 4  Unnamed: 5  1999  Unnamed: 7  \
# count    4.0       4.000         4.0         4.0   4.0       4.000
# unique   4.0       4.000         4.0         4.0   4.0       4.000
# top      7.8       0.058         7.7         7.9   7.7       0.057
# freq     1.0       1.000         1.0         1.0   1.0       1.000
#
#         Unnamed: 8  Unnamed: 9  ...  Unnamed: 68  Unnamed: 69  2015  \
# count          4.0         4.0  ...         25.0           25  25.0
# unique         4.0         4.0  ...         24.0           22  24.0
# ...

# %%
# Import Data
RG20032006 = pd.read_csv("infant_race/RaceGender2003_2006.txt")
RG20032006 .head()
# Out:
#                                      Notes\t"State"\t"State Code"\t"County"\t"County Code"\t"Mother's Bridged Race"\t"Mother's Bridged Race Code"\t"Gender"\t"Gender Code"\t"Year of Death"\t"Year of Death Code"\tDeaths\tBirths\tDeath Rate
# \t"Alabama"\t"01"\t"Jefferson County   AL"\t"01073"\t"Black or African American"\t"2...
# \t"Alabama"\t"01"\t"Jefferson County   AL"\t"01073"\t"Black or African American"\t"2...
# \t"Alabama"\t"01"\t"Jefferson County   AL"\t"01073"\t"Black or African American"\t"2...
# \t"Alabama"\t"01"\t"Jefferson County   AL"\t"01073"\t"Black or African American"\t"2...
# \t"Alabama"\t"01"\t"Jefferson County   AL"\t"01073"\t"Black or African American"\t"2...

# %%
RG20032006.shape
# Out:
# (2700, 1)

# %%
RG20032006.describe()
# Out:
#        Notes\t"State"\t"State Code"\t"County"\t"County Code"\t"Mother's Bridged Race"\t"Mother's Bridged Race Code"\t"Gender"\t"Gender Code"\t"Year of Death"\t"Year of Death Code"\tDeaths\tBirths\tDeath Rate
# count                                                2652
# unique                                               2652
# top      GA"\t"13135"\t"Black or African American"\t"2...
# freq                                                    1

# %% [markdown]
# ## C:\Users\carol\Documents\GitHub\FinalProject-MachineLearning\data\DRAFT\other_factors

# %%
# Import Data
from tabula import read_pdf


MCH2016-17 = pd.read_pdf("other_factors/Selected-2016-2017-MCH-Indicators-Aggregate-by-Site_508.pdf")
MCH2016-17
# Out:
#   File "<ipython-input-74-ba55f36c77a0>", line 5
#     MCH2016-17 = pd.read_pdf("other_factors/Selected-2016-2017-MCH-Indicators-Aggregate-by-Site_508.pdf")
#                                                                                                          ^
# SyntaxError: can't assign to operator

# %% [markdown]
# ## C:\Users\carol\Documents\GitHub\FinalProject-MachineLearning\data\DRAFT\poverty_rate

# %%
# Import New data
# Import Data
ohioMI2017 = pd.read_csv("poverty_rate/median income per county 2017.csv")

ohioMI2017.head()
# Out:
#             Id  Id2 Geography   Target Geo Id  Target Geo Id2  \
# 0  0400000US39   39      Ohio     0400000US39              39
# 1  0400000US39   39      Ohio  0500000US39001           39001
# 2  0400000US39   39      Ohio  0500000US39003           39003
# 3  0400000US39   39      Ohio  0500000US39005           39005
# 4  0400000US39   39      Ohio  0500000US39007           39007
#
#            Geographic Area Geographic Area.1  Dollar  Margin of Error
# 0                     Ohio              Ohio   52407              153
# 1      Ohio - Adams County      Adams County   36320             2651
# 2      Ohio - Allen County      Allen County   47905             1708
# 3    Ohio - Ashland County    Ashland County   50893             1608
# 4  Ohio - Ashtabula County  Ashtabula County   43017             1597

# %%
ohioMI2017.shape
# Out:
# (89, 9)

# %%
ohioMI2017.describe()
# Out:
#         Id2  Target Geo Id2         Dollar  Margin of Error
# count  89.0       89.000000      89.000000        89.000000
# mean   39.0    38649.247191   51749.674157      1955.988764
# std     0.0     4139.497486   10077.248313       834.719693
# min    39.0       39.000000   36320.000000       153.000000
# 25%    39.0    39043.000000   44820.000000      1509.000000
# 50%    39.0    39087.000000   49997.000000      1900.000000
# 75%    39.0    39131.000000   56193.000000      2425.000000
# max    39.0    39175.000000  100229.000000      5489.000000
