# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('antibiotics vs apgar.csv')
df
# Out:
#     Antibiotics for Mother Code Antibiotics for Mother  % of Total Births  \
# 0                             1                    Yes             0.0001
# 1                             1                    Yes             0.0006
# 2                             1                    Yes             0.0005
# 3                             1                    Yes             0.0005
# 4                             1                    Yes             0.0008
# 5                             1                    Yes             0.0013
# 6                             1                    Yes             0.0026
# 7                             1                    Yes             0.0060
# 8                             1                    Yes             0.0277
# 9                             1                    Yes             0.2076
# 10                            1                    Yes             0.0042
# 11                            1                    Yes             0.0003
# ...

# %%
df2 = df[['Average Age of Mother (years)','Average Birth Weight (grams)','Average Number of Prenatal Visits','Five Minute APGAR Score']]
df2.head()
# Out:
#    Average Age of Mother (years)  Average Birth Weight (grams)  \
# 0                          28.55                       2074.08
# 1                          28.66                       1546.24
# 2                          28.35                       2110.15
# 3                          28.67                       2363.17
# 4                          28.56                       2463.62
#
#    Average Number of Prenatal Visits  Five Minute APGAR Score
# 0                               7.89                      0.0
# 1                               7.34                      1.0
# 2                               8.93                      2.0
# 3                               9.29                      3.0
# 4                               9.95                      4.0

# %%
df3= df2.dropna()

# %%
df4 = df3[['Five Minute APGAR Score','Average Birth Weight (grams)']]
df4
# Out:
#     Five Minute APGAR Score  Average Birth Weight (grams)
# 0                       0.0                       2074.08
# 1                       1.0                       1546.24
# 2                       2.0                       2110.15
# 3                       3.0                       2363.17
# 4                       4.0                       2463.62
# 5                       5.0                       2552.63
# 6                       6.0                       2618.78
# 7                       7.0                       2742.62
# 8                       8.0                       3038.01
# 9                       9.0                       3257.31
# 10                     10.0                       3317.03
# 13                      0.0                       2053.51
# 14                      1.0                       1441.19
# 15                      2.0                       2225.90
# 16                      3.0                       2492.50
# ...

# %%
lines = df4.plot.line()

# %%
bars = df4.plot.bar()

# %%
df4.hist(column='Five Minute APGAR Score')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000015671014048>]],
#       dtype=object)
