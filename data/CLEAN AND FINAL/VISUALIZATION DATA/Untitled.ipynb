# %%
import pandas as pd
import matplotlib as plt

# %%
# Import Data
cdcData1618 = pd.read_csv("../cdcData1618.csv", sep='|')

cdcData1618
# Out:
#     State of Residence  State of Residence Code        County of Residence  \
# 0              Alabama                      1.0         Baldwin County, AL
# 1              Alabama                      1.0         Calhoun County, AL
# 2              Alabama                      1.0          Etowah County, AL
# 3              Alabama                      1.0         Houston County, AL
# 4              Alabama                      1.0       Jefferson County, AL
# 5              Alabama                      1.0             Lee County, AL
# 6              Alabama                      1.0         Madison County, AL
# 7              Alabama                      1.0          Mobile County, AL
# 8              Alabama                      1.0      Montgomery County, AL
# 9              Alabama                      1.0          Morgan County, AL
# 10             Alabama                      1.0          Shelby County, AL
# ...

# %%
cdcData1618 = pd.DataFrame({'State of Residence': StateofResidence,
...                    'Average Number of Prenatal Visits': AverageNumberofPrenatalVisits}, index=index)
>>> ax = cdcData1618.plot.bar(rot=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-34f348d03e08> in <module>
# ----> 1 cdcData1618 = pd.DataFrame({'State of Residence': StateofResidence,
#       2                    'Average Number of Prenatal Visits': AverageNumberofPrenatalVisits}, index=index)
#       3 ax = cdcData1618.plot.bar(rot=0)
#
# NameError: name 'StateofResidence' is not defined
