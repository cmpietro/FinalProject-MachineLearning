# %%
# Include this line to make plots interactive
# %matplotlib notebook
import requests 
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter

# %%
Mothers_Bridged_Race_Hispanic_Origin = pd.read_csv('Death Rate By Mothers Bridged Race and Hispanic Origin.csv')
Mothers_Bridged_Race_Hispanic_Origin.head()
# Out:
#   Mothers Bridged Race/Hispanic Origin  \
# 0                              Mexican
# 1                         Puerto Rican
# 2            Central or South American
# 3           Other and Unknown Hispanic
# 4                   Non-Hispanic White
#
#    Mothers Bridged Race/Hispanic Origin Code  Deaths  Births  Death Rate
# 0                                          2      18    3095        5.82
# 1                                          3      15    1836        8.17
# 2                                          4      13    1586        8.20
# 3                                          5      11     806       13.65
# 4                                          6     537  100151        5.36

# %%
Mothers_Bridged_Race_Hispanic_Origin.dtypes
# Out:
# Mothers Bridged Race/Hispanic Origin          object
# Mothers Bridged Race/Hispanic Origin Code      int64
# Deaths                                         int64
# Births                                         int64
# Death Rate                                   float64
# dtype: object

# %%
Mothers_Bridged_Race_Hispanic_Origin_Clean=Mothers_Bridged_Race_Hispanic_Origin[['Mothers Bridged Race/Hispanic Origin','Death Rate']]
Mothers_Bridged_Race_Hispanic_Origin_Clean.head()
# Out:
#   Mothers Bridged Race/Hispanic Origin  Death Rate
# 0                              Mexican        5.82
# 1                         Puerto Rican        8.17
# 2            Central or South American        8.20
# 3           Other and Unknown Hispanic       13.65
# 4                   Non-Hispanic White        5.36

# %%
#TopCausesClean = TopCausesClean.set_index("15 Leading Causes of Death (Infants)")
Mothers_Bridged_Race_Hispanic_Origin_Clean.set_index("Mothers Bridged Race/Hispanic Origin",drop=True,inplace=True)
Mothers_Bridged_Race_Hispanic_Origin_Clean
# Out:
#                                       Death Rate
# Mothers Bridged Race/Hispanic Origin
# Mexican                                     5.82
# Puerto Rican                                8.17
# Central or South American                   8.20
# Other and Unknown Hispanic                 13.65
# Non-Hispanic White                          5.36
# Non-Hispanic Black                         14.48
# Non-Hispanic other races                    5.51
# Origin unknown or not stated               60.19

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
Mothers_Bridged_Race_Hispanic_Origin_Clean.plot(kind="barh", figsize=(10,3),color="darkmagenta")
#TopCausesClean.plot(kind="barh",figsize=(7,5))
# Set a title for the chart
plt.title("Death Rate by Mother's Bridged Race/Hispanic Origin")
plt.savefig("DeathRateByMothersBridgedRaceand HispanicOrigin_2017Data.png", bbox_inches = "tight")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1000">
