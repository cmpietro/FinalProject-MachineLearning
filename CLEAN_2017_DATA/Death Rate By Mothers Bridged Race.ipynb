# %%
# Include this line to make plots interactive
# %matplotlib notebook
import requests 
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter

# %%
Mothers_Bridged_Race = pd.read_csv('Death Rate By Mothers Bridged Race.csv')
Mothers_Bridged_Race.head()
# Out:
#         Mothers Bridged Race  Deaths  Births  Death Rate
# 0  Asian or Pacific Islander      27    4884        5.53
# 1  Black or African American     362   25268       14.33
# 2                      White     591  106410        5.55

# %%
Mothers_Bridged_Race.dtypes
# Out:
# Mothers Bridged Race     object
# Deaths                    int64
# Births                    int64
# Death Rate              float64
# dtype: object

# %%
Mothers_Bridged_Race_Clean=Mothers_Bridged_Race[['Mothers Bridged Race','Death Rate']]
Mothers_Bridged_Race_Clean.head()
# Out:
#         Mothers Bridged Race  Death Rate
# 0  Asian or Pacific Islander        5.53
# 1  Black or African American       14.33
# 2                      White        5.55

# %%
#TopCausesClean = TopCausesClean.set_index("15 Leading Causes of Death (Infants)")
Mothers_Bridged_Race_Clean.set_index("Mothers Bridged Race",drop=True,inplace=True)
Mothers_Bridged_Race_Clean
# Out:
#                            Death Rate
# Mothers Bridged Race
# Asian or Pacific Islander        5.53
# Black or African American       14.33
# White                            5.55

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
Mothers_Bridged_Race_Clean.plot(kind="barh", figsize=(10,3),color="darkmagenta")
#TopCausesClean.plot(kind="barh",figsize=(7,5))
# Set a title for the chart
plt.title("Death Rate by Mother's Bidged Race")
plt.savefig("DeathRateByMothersBridgedRace_2017Data.png", bbox_inches = "tight")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1000">
