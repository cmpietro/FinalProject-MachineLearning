# %%
#! pip install plotly
#!pip install psutil requests
# Include this line to make plots interactive
# %matplotlib notebook
import requests 
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter

# %%
TopCauses = pd.read_csv('15 Leading Causes ofInfant Death.csv')
TopCauses.head()
# Out:
#                 15 Leading Causes of Death (Infants)  \
# 0  Disorders related to short gestation and low b...
# 1  Congenital malformations, deformations and chr...
# 2  Newborn affected by maternal complications of ...
# 3                       Sudden infant death syndrome
# 4                Accidents (unintentional injuries)
#
#   15 Leading Causes of Death (Infants) Code  Deaths  Births  Death Rate
# 0                                 GR130-088     212  136832        1.55
# 1                                 GR130-118     180  136832        1.32
# 2                                 GR130-074      80  136832        0.58
# 3                                 GR130-135      67  136832        0.49
# 4                                 GR130-139      60  136832        0.44

# %%
TopCauses.dtypes
# Out:
# 15 Leading Causes of Death (Infants)          object
# 15 Leading Causes of Death (Infants) Code     object
# Deaths                                         int64
# Births                                         int64
# Death Rate                                   float64
# dtype: object

# %%
TopCausesClean=TopCauses[['15 Leading Causes of Death (Infants)','Death Rate']]
TopCausesClean.head()
# Out:
#                 15 Leading Causes of Death (Infants)  Death Rate
# 0  Disorders related to short gestation and low b...        1.55
# 1  Congenital malformations, deformations and chr...        1.32
# 2  Newborn affected by maternal complications of ...        0.58
# 3                       Sudden infant death syndrome        0.49
# 4                Accidents (unintentional injuries)         0.44

# %%
#TopCausesClean = TopCausesClean.set_index("15 Leading Causes of Death (Infants)")
TopCausesClean.set_index("15 Leading Causes of Death (Infants)",drop=True,inplace=True)
TopCausesClean
# Out:
#                                                     Death Rate
# 15 Leading Causes of Death (Infants)
# Disorders related to short gestation and low bi...        1.55
# Congenital malformations, deformations and chro...        1.32
# Newborn affected by maternal complications of p...        0.58
# Sudden infant death syndrome                              0.49
# Accidents (unintentional injuries)                        0.44
# Newborn affected by complications of placenta, ...        0.33
# Bacterial sepsis of newborn                               0.18
# Diseases of the circulatory system                        0.15
# Neonatal hemorrhage                                       0.12
# Respiratory distress of newborn                           0.12
# Atelectasis                                               0.10
# Assault (homicide)                                        0.10
# Necrotizing enterocolitis of newborn                      0.09
# ...

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
TopCausesClean.plot(kind="barh", figsize=(10,3),color="darkmagenta")
#TopCausesClean.plot(kind="barh",figsize=(7,5))
# Set a title for the chart
plt.title("Death Rate by Top Causes of Death (Infants)")
plt.savefig("DeathRateBy15LeadingCausesOfDeath_2017Data.png", bbox_inches = "tight")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1000">
