# %%
# Include this line to make plots interactive
# %matplotlib notebook
import requests 
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter

# %%
Maternal_Education = pd.read_csv('Death Rate By Mothers Education.csv')
Maternal_Education.head()
# Out:
#                         Mothers Education  Mothers Education Code  Deaths  \
# 0                       8th grade or less                       1      43
# 1  9th through 12th grade with no diploma                       2     148
# 2   High school graduate or GED completed                       3     349
# 3   Some college credit, but not a degree                       4     178
# 4               Associate degree (AA, AS)                       5      78
#
#    Births  Death Rate
# 0    4819        8.92
# 1   13242       11.18
# 2   37301        9.36
# 3   26806        6.64
# 4   12616        6.18

# %%
Maternal_Education.dtypes
# Out:
# Mothers Education          object
# Mothers Education Code      int64
# Deaths                      int64
# Births                      int64
# Death Rate                float64
# dtype: object

# %%
Maternal_EducationClean=Maternal_Education[['Mothers Education','Death Rate']]
Maternal_EducationClean.head()
# Out:
#                         Mothers Education  Death Rate
# 0                       8th grade or less        8.92
# 1  9th through 12th grade with no diploma       11.18
# 2   High school graduate or GED completed        9.36
# 3   Some college credit, but not a degree        6.64
# 4               Associate degree (AA, AS)        6.18

# %%
#TopCausesClean = TopCausesClean.set_index("15 Leading Causes of Death (Infants)")
Maternal_EducationClean.set_index("Mothers Education",drop=True,inplace=True)
Maternal_EducationClean
# Out:
#                                         Death Rate
# Mothers Education
# 8th grade or less                             8.92
# 9th through 12th grade with no diploma       11.18
# High school graduate or GED completed         9.36
# Some college credit, but not a degree         6.64
# Associate degree (AA, AS)                     6.18
# Bachelor's degree (BA, AB, BS)                4.11
# Master's degree (MA, MS, MBA)                 3.02
#  Professional Degree (Phd,Etc.)               3.25
# Unknown or Not Stated                        81.22

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
Maternal_EducationClean.plot(kind="barh", figsize=(6,2),color="darkmagenta")
#TopCausesClean.plot(kind="barh",figsize=(7,5))
# Set a title for the chart
plt.title("Death Rate by Mothers's Education")
plt.savefig("DeathRateByMothersEducation_2017Data.png", bbox_inches = "tight")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="600">
